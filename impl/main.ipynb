# %%
from main import *

# %%
dirname = 'sample'
print('\ncurrent directory : {}\n'.format(dirname))
model = MopReM(dirname)
# Out:
# current directory : sample

# %%
model.pre_process()
# Out:
# level0 Complete, nx: 1, ny: 1, width: 959, height: 959
# level1 Complete, nx: 6, ny: 6, width: 274, height: 274
# level2 Complete, nx: 10, ny: 10, width: 175, height: 175
# level3 Complete, nx: 15, ny: 15, width: 120, height: 120
# level4 Complete, nx: 19, ny: 19, width: 96, height: 96
# Pre processing time: 1.1s

# %%
model.demoire()
# Out:
# Demoiring time: 9.8s

# %%
model.post_process()
# Out:
# Post processing time: 4.3s
