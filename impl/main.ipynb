# %%
from moprem import *

# %%
imgdir = 'sample'
print('current directory : {}'.format(imgdir))
model = MopReM(imgdir)
model.pre().demoire()
# Out:
# current directory : sample
# C:\Users\lucetre\Documents\semester\MopReM\result\sample\pre
#   Pre processing time			+0.83s
# background
# grayscale

# %%
model.post().eval()

# %%
imgdir = 'sample'
print('current directory : {}'.format(imgdir))
model = MopReM(imgdir)
model.pre().demoire().post().eval()
# Out:
# current directory : sample
# C:\Users\lucetre\Documents\semester\MopReM\result\sample\pre
#   Pre processing time			+0.39s
#   Remove background processing time	+4.87s
#   Post processing time			+0.62s
# C:\Users\lucetre\Documents\semester\MopReM\result\sample\post\clean0.png
#   Eval time				+11.12s

# %%
imgdir = 'physics'
print('current directory : {}'.format(imgdir))
model = MopReM(imgdir)
model.pre().demoire().post().eval()
# Out:
# current directory : physics
# C:\Users\lucetre\Documents\semester\MopReM\result\physics\pre
#   Pre processing time			+3.15s
#   Remove background processing time	+13.77s
#   Post processing time			+3.79s
# C:\Users\lucetre\Documents\semester\MopReM\result\physics\post\clean0.png
#   Eval time				+15.23s
