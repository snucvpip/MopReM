# %%
from moprem import *

# %%
imgdir = 'sample'
print('current directory : {}'.format(imgdir))
model = MopReM(imgdir)
model.pre().demoire().post().eval()
# Out:
# current directory : sample
#   Pre processing time			+0.40s
#   Demoire processing time		+0.66s
#   Post processing time			+0.04s
#     Source	MSE: 5449.06	PSNR: 10.77	SSIM: 0.25
#     Clear	MSE: 3596.47	PSNR: 12.57	SSIM: 0.59
#   Eval time				+5.59s

# %%
imgdir = 'physics'
print('current directory : {}'.format(imgdir))
model = MopReM(imgdir)
model.pre().demoire().post().eval()
# Out:
# current directory : physics
#   Pre processing time			+3.48s
#   Demoire processing time		+3.26s
#   Post processing time			+0.27s
#     Source	MSE: 6052.50	PSNR: 10.31	SSIM: 0.22
#     Clear	MSE: 1645.64	PSNR: 15.97	SSIM: 0.71
#   Eval time				+10.08s

# %%
imgdir = 'snipping'
print('current directory : {}'.format(imgdir))
model = MopReM(imgdir)
model.pre().demoire().post().eval()
# Out:
# current directory : snipping
#   Pre processing time			+3.63s
#   Demoire processing time		+5.19s
#   Post processing time			+0.55s
#     Source	MSE: 9513.29	PSNR: 8.35	SSIM: 0.33
#     Clear	MSE: 3077.09	PSNR: 13.25	SSIM: 0.42
#   Eval time				+10.55s

# %% [markdown]
# ### Experiments

# %%
from moprem import *

# %%
imgdir = 'graph_laptop'
print('current directory : {}'.format(imgdir))
model = MopReM(imgdir)
model.pre().demoire().post().eval()
# Out:
# current directory : graph_laptop
#   Pre processing time			+2.78s
#   Demoire processing time		+3.36s
#   Post processing time			+0.20s
#     Source	MSE: 3291.66	PSNR: 12.96	SSIM: 0.23
#     Clear	MSE: 1469.45	PSNR: 16.46	SSIM: 0.81
#   Eval time				+8.59s

# %%
imgdir = 'graph_desktop'
print('current directory : {}'.format(imgdir))
model = MopReM(imgdir)
model.pre().demoire().post().eval()
# Out:
# current directory : graph_desktop
#   Pre processing time			+1.70s
#   Demoire processing time		+3.65s
#   Post processing time			+0.27s
#     Source	MSE: 8864.85	PSNR: 8.65	SSIM: 0.08
#     Clear	MSE: 4475.38	PSNR: 11.62	SSIM: 0.13
#   Eval time				+8.54s

# %%
imgdir = 'intro_laptop'
print('current directory : {}'.format(imgdir))
model = MopReM(imgdir)
model.pre().demoire().post().eval(110)
# Out:
# current directory : intro_laptop
#   Pre processing time			+2.30s
#   Demoire processing time		+2.78s
#   Post processing time			+0.18s
#     Source	MSE: 2318.95	PSNR: 14.48	SSIM: 0.57
#     Clear	MSE: 1316.65	PSNR: 16.94	SSIM: 0.89
#   Eval time				+8.05s

# %%
imgdir = 'intro_desktop'
print('current directory : {}'.format(imgdir))
model = MopReM(imgdir)
model.pre().demoire().post().eval(110)
# Out:
# current directory : intro_desktop
#   Pre processing time			+2.21s
#   Demoire processing time		+4.41s
#   Post processing time			+0.29s
#     Source	MSE: 8411.22	PSNR: 8.88	SSIM: 0.10
#     Clear	MSE: 3782.53	PSNR: 12.35	SSIM: 0.22
#   Eval time				+8.52s

# %%
imgdir = 'lecture_laptop'
print('current directory : {}'.format(imgdir))
model = MopReM(imgdir)
model.pre().demoire().post().eval(120)
# Out:
# current directory : lecture_laptop
#   Pre processing time			+3.02s
#   Demoire processing time		+3.38s
#   Post processing time			+0.22s
#     Source	MSE: 2768.45	PSNR: 13.71	SSIM: 0.46
#     Clear	MSE: 1155.99	PSNR: 17.50	SSIM: 0.89
#   Eval time				+9.67s

# %%
imgdir = 'lecture_desktop'
print('current directory : {}'.format(imgdir))
model = MopReM(imgdir)
model.pre().demoire().post().eval(120)
# Out:
# current directory : lecture_desktop
#   Pre processing time			+2.33s
#   Demoire processing time		+3.80s
#   Post processing time			+0.17s
#     Source	MSE: 5235.78	PSNR: 10.94	SSIM: 0.11
#     Clear	MSE: 888.72	PSNR: 18.64	SSIM: 0.87
#   Eval time				+8.72s

# %%
imgdir = 'table_laptop'
print('current directory : {}'.format(imgdir))
model = MopReM(imgdir)
model.pre().demoire().post().eval(120)
# Out:
# current directory : table_laptop
#   Pre processing time			+2.61s
#   Demoire processing time		+2.85s
#   Post processing time			+0.19s
#     Source	MSE: 2781.50	PSNR: 13.69	SSIM: 0.32
#     Clear	MSE: 1100.10	PSNR: 17.72	SSIM: 0.83
#   Eval time				+7.72s

# %%
imgdir = 'table_desktop'
print('current directory : {}'.format(imgdir))
model = MopReM(imgdir)
model.pre().demoire().post().eval()
# Out:
# current directory : table_desktop
#   Pre processing time			+2.33s
#   Demoire processing time		+5.25s
#   Post processing time			+0.34s
#     Source	MSE: 9160.35	PSNR: 8.51	SSIM: 0.08
#     Clear	MSE: 4411.67	PSNR: 11.68	SSIM: 0.14
#   Eval time				+8.34s

# %%
imgdir = 'text_laptop'
print('current directory : {}'.format(imgdir))
model = MopReM(imgdir)
model.pre().demoire().post().eval(110)
# Out:
# current directory : text_laptop
#   Pre processing time			+2.58s
#   Demoire processing time		+2.85s
#   Post processing time			+0.21s
#     Source	MSE: 3162.77	PSNR: 13.13	SSIM: 0.39
#     Clear	MSE: 1729.00	PSNR: 15.75	SSIM: 0.88
#   Eval time				+8.74s

# %%
imgdir = 'text_desktop'
print('current directory : {}'.format(imgdir))
model = MopReM(imgdir)
model.pre().demoire().post().eval(90)
# Out:
# current directory : text_desktop
#   Pre processing time			+2.37s
#   Demoire processing time		+4.28s
#   Post processing time			+0.19s
#     Source	MSE: 5999.44	PSNR: 10.35	SSIM: 0.21
#     Clear	MSE: 1571.75	PSNR: 16.17	SSIM: 0.70
#   Eval time				+7.87s
