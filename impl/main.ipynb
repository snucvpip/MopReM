# %%
from moprem import *

# %%
dirname = 'sample'
print('\ncurrent directory : {}\n'.format(dirname))
model = MopReM(dirname)
# Out:
# current directory : sample

# %%
model.pre()
# Out:
#   Pre processing time			+1.08s

# %%
model.demoire()
# Out:
#   Demoireing time			+10.60s

# %%
model.post()
# Out:
#   Post processing time			+1.29s

# %%
model.eval()
# Out:
# C:\Users\lucetre\Documents\semester\MopReM\result/post_process\sample\clean3.png
#   Eval time				+37.47s
